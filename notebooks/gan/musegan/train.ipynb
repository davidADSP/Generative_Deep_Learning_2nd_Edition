# %% [markdown]
# # 🎶 Music Generation - MuseGAN

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own MuseGAN model to generate music in the style of the Bach chorales

# %% [markdown]
# ## Table of contents
# 0. [Parameters](#parameters)
# 1. [Prepare the Data](#prepare)
# 2. [Build the Model](#build)
# 3. [Train the Model](#train)
# 4. [Generate music](#generate)

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

np.set_printoptions(suppress=True)
import matplotlib.pyplot as plt

plt.style.use("seaborn-colorblind")

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, initializers, metrics

from music21 import stream, tempo, note, duration

from utils.music import notes_to_midi, draw_score, draw_bar
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
BATCH_SIZE = 64

N_BARS = 2
N_STEPS_PER_BAR = 16
MAX_PITCH = 83
N_PITCHES = MAX_PITCH + 1
Z_DIM = 32


CRITIC_STEPS = 5
GP_WEIGHT = 10
CRITIC_LEARNING_RATE = 0.001
GENERATOR_LEARNING_RATE = 0.001
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
EPOCHS = 6000
LOAD_MODEL = True

# %% [markdown]
# ## 1. Prepare the Data

# %%
# Load the data
file = os.path.join("/app/data/bach-chorales/Jsb16thSeparated.npz")
with np.load(file, encoding="bytes", allow_pickle=True) as f:
    data = f["train"]

# %%
N_SONGS = len(data)
print(f"{N_SONGS} chorales in the dataset")
chorale = data[0]
N_BEATS, N_TRACKS = chorale.shape
print(f"{N_BEATS, N_TRACKS} shape of chorale 0")
print("\nChorale 0")
print(chorale[:8])
# Out:
# 229 chorales in the dataset
# (192, 4) shape of chorale 0
#
# Chorale 0
# [[74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [75. 70. 58. 55.]
#  [75. 70. 58. 55.]
#  [75. 70. 60. 55.]
#  [75. 70. 60. 55.]]

# %%
two_bars = np.array([x[: (N_STEPS_PER_BAR * N_BARS)] for x in data])
two_bars = np.array(np.nan_to_num(two_bars, nan=MAX_PITCH), dtype=int)
two_bars = two_bars.reshape([N_SONGS, N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"Two bars shape {two_bars.shape}")
# Out:
# Two bars shape (229, 2, 16, 4)

# %%
data_binary = np.eye(N_PITCHES)[two_bars]
data_binary[data_binary == 0] = -1
data_binary = data_binary.transpose([0, 1, 2, 4, 3])
INPUT_DIM = data_binary.shape[1:]
print(f"Data binary shape {data_binary.shape}")
# Out:
# Data binary shape (229, 2, 16, 84, 4)

# %% [markdown]
# ## 2. Build the GAN <a name="build"></a>

# %%
# Some helper functions

initializer = initializers.RandomNormal(mean=0.0, stddev=0.02)


def conv(x, f, k, s, p):
    x = layers.Conv3D(filters=f, kernel_size=k, padding=p, strides=s, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)
    return x


def conv_t(x, f, k, s, a, p, bn):
    x = layers.Conv2DTranspose(filters=f, kernel_size=k, padding=p, strides=s, kernel_initializer=initializer)(x)
    if bn:
        x = layers.BatchNormalization(momentum=0.9)(x)

    x = layers.Activation(a)(x)
    return x

# %%
def TemporalNetwork():
    input_layer = layers.Input(shape=(Z_DIM,), name="temporal_input")
    x = layers.Reshape([1, 1, Z_DIM])(input_layer)
    x = conv_t(x, f=1024, k=(2, 1), s=(1, 1), a="relu", p="valid", bn=True)
    x = conv_t(x, f=Z_DIM, k=(N_BARS - 1, 1), s=(1, 1), a="relu", p="valid", bn=True)
    output_layer = layers.Reshape([N_BARS, Z_DIM])(x)
    return models.Model(input_layer, output_layer)


TemporalNetwork().summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  temporal_input (InputLayer)  [(None, 32)]             0
#
#  reshape_24 (Reshape)        (None, 1, 1, 32)          0
#
#  conv2d_transpose_39 (Conv2D  (None, 2, 1, 1024)       66560
#  Transpose)
#
#  batch_normalization_39 (Bat  (None, 2, 1, 1024)       4096
#  chNormalization)
#
#  activation_44 (Activation)  (None, 2, 1, 1024)        0
#
#  conv2d_transpose_40 (Conv2D  (None, 2, 1, 32)         32800
#  Transpose)
#
#  batch_normalization_40 (Bat  (None, 2, 1, 32)         128
#  chNormalization)
#
#  activation_45 (Activation)  (None, 2, 1, 32)          0
#
#  reshape_25 (Reshape)        (None, 2, 32)             0
#
# =================================================================
# Total params: 103,584
# Trainable params: 101,472
# Non-trainable params: 2,112
# _________________________________________________________________

# %%
def BarGenerator():

    input_layer = layers.Input(shape=(Z_DIM * 4,), name="bar_generator_input")

    x = layers.Dense(1024)(input_layer)
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.Activation("relu")(x)
    x = layers.Reshape([2, 1, 512])(x)

    x = conv_t(x, f=512, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(1, 7), s=(1, 7), a="relu", p="same", bn=True)
    x = conv_t(x, f=1, k=(1, 12), s=(1, 12), a="tanh", p="same", bn=False)

    output_layer = layers.Reshape([1, N_STEPS_PER_BAR, N_PITCHES, 1])(x)

    return models.Model(input_layer, output_layer)


BarGenerator().summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bar_generator_input (InputL  [(None, 128)]            0
#  ayer)
#
#  dense_7 (Dense)             (None, 1024)              132096
#
#  batch_normalization_41 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  activation_46 (Activation)  (None, 1024)              0
#
#  reshape_26 (Reshape)        (None, 2, 1, 512)         0
#
#  conv2d_transpose_41 (Conv2D  (None, 4, 1, 512)        524800
#  Transpose)
#
#  batch_normalization_42 (Bat  (None, 4, 1, 512)        2048
#  chNormalization)
#
#  activation_47 (Activation)  (None, 4, 1, 512)         0
#
#  conv2d_transpose_42 (Conv2D  (None, 8, 1, 256)        262400
#  Transpose)
#
#  batch_normalization_43 (Bat  (None, 8, 1, 256)        1024
#  chNormalization)
#
#  activation_48 (Activation)  (None, 8, 1, 256)         0
#
#  conv2d_transpose_43 (Conv2D  (None, 16, 1, 256)       131328
#  Transpose)
#
#  batch_normalization_44 (Bat  (None, 16, 1, 256)       1024
#  chNormalization)
#
#  activation_49 (Activation)  (None, 16, 1, 256)        0
#
#  conv2d_transpose_44 (Conv2D  (None, 16, 7, 256)       459008
#  Transpose)
#
#  batch_normalization_45 (Bat  (None, 16, 7, 256)       1024
#  chNormalization)
#
#  activation_50 (Activation)  (None, 16, 7, 256)        0
#
#  conv2d_transpose_45 (Conv2D  (None, 16, 84, 1)        3073
#  Transpose)
#
#  activation_51 (Activation)  (None, 16, 84, 1)         0
#
#  reshape_27 (Reshape)        (None, 1, 16, 84, 1)      0
#
# =================================================================
# Total params: 1,521,921
# Trainable params: 1,517,313
# Non-trainable params: 4,608
# _________________________________________________________________

# %%
def Generator():

    chords_input = layers.Input(shape=(Z_DIM,), name="chords_input")
    style_input = layers.Input(shape=(Z_DIM,), name="style_input")
    melody_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="melody_input")
    groove_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="groove_input")

    # CHORDS -> TEMPORAL NETWORK
    chords_tempNetwork = TemporalNetwork()
    chords_over_time = chords_tempNetwork(chords_input)  # [n_bars, z_dim]

    # MELODY -> TEMPORAL NETWORK
    melody_over_time = [None] * N_TRACKS  # list of n_tracks [n_bars, z_dim] tensors
    melody_tempNetwork = [None] * N_TRACKS
    for track in range(N_TRACKS):
        melody_tempNetwork[track] = TemporalNetwork()
        melody_track = layers.Lambda(lambda x, track=track: x[:, track, :])(melody_input)
        melody_over_time[track] = melody_tempNetwork[track](melody_track)

    # CREATE BAR GENERATOR FOR EACH TRACK
    barGen = [None] * N_TRACKS
    for track in range(N_TRACKS):
        barGen[track] = BarGenerator()

    # CREATE OUTPUT FOR EVERY TRACK AND BAR
    bars_output = [None] * N_BARS
    c = [None] * N_BARS
    for bar in range(N_BARS):
        track_output = [None] * N_TRACKS

        c[bar] = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(chords_over_time)  # [z_dim]
        s = style_input  # [z_dim]

        for track in range(N_TRACKS):

            m = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(melody_over_time[track])  # [z_dim]
            g = layers.Lambda(lambda x, track=track: x[:, track, :])(groove_input)  # [z_dim]

            z_input = layers.Concatenate(axis=1, name="total_input_bar_{}_track_{}".format(bar, track))(
                [c[bar], s, m, g]
            )

            track_output[track] = barGen[track](z_input)

        bars_output[bar] = layers.Concatenate(axis=-1)(track_output)

    generator_output = layers.Concatenate(axis=1, name="concat_bars")(bars_output)

    return models.Model([chords_input, style_input, melody_input, groove_input], generator_output)


generator = Generator()
# generator.summary()

# %%
def Critic():
    critic_input = layers.Input(shape=INPUT_DIM, name="critic_input")

    x = critic_input

    x = conv(x, f=128, k=(2, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(N_BARS - 1, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(1, 1, 12), s=(1, 1, 12), p="same")
    x = conv(x, f=128, k=(1, 1, 7), s=(1, 1, 7), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=256, k=(1, 4, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=512, k=(1, 3, 1), s=(1, 2, 1), p="same")

    x = layers.Flatten()(x)

    x = layers.Dense(1024, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)

    critic_output = layers.Dense(1, activation=None, kernel_initializer=initializer)(x)

    return models.Model(critic_input, critic_output)


critic = Critic()
# critic.summary()

# %%
class MuseGAN(keras.Model):
    def __init__(self, critic, generator, latent_dim, critic_steps, gp_weight):
        super(MuseGAN, self).__init__()
        self.critic = critic
        self.generator = generator
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight

    def compile(self, c_optimizer, g_optimizer):
        super(MuseGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        self.c_wass_loss_metric = metrics.Mean(name="c_wass_loss")
        self.c_gp_metric = metrics.Mean(name="c_gp")
        self.c_loss_metric = metrics.Mean(name="c_loss")
        self.g_loss_metric = metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.c_loss_metric, self.c_wass_loss_metric, self.c_gp_metric, self.g_loss_metric]

    def gradient_penalty(self, batch_size, real_images, fake_images):
        alpha = tf.random.normal([batch_size, 1, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            pred = self.critic(interpolated, training=True)

        grads = gp_tape.gradient(pred, [interpolated])[0]
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        for i in range(self.critic_steps):
            chords_random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            style_random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            melody_random_latent_vectors = tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim))
            groove_random_latent_vectors = tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim))

            random_latent_vectors = [
                chords_random_latent_vectors,
                style_random_latent_vectors,
                melody_random_latent_vectors,
                groove_random_latent_vectors,
            ]

            with tf.GradientTape() as tape:
                fake_images = self.generator(random_latent_vectors, training=True)
                fake_predictions = self.critic(fake_images, training=True)
                real_predictions = self.critic(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(real_predictions)
                c_gp = self.gradient_penalty(batch_size, real_images, fake_images)
                c_loss = c_wass_loss + c_gp * self.gp_weight

            c_gradient = tape.gradient(c_loss, self.critic.trainable_variables)
            self.c_optimizer.apply_gradients(zip(c_gradient, self.critic.trainable_variables))

        chords_random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        style_random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        melody_random_latent_vectors = tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim))
        groove_random_latent_vectors = tf.random.normal(shape=(batch_size, N_TRACKS, self.latent_dim))

        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]

        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_predictions = self.critic(fake_images, training=True)
            g_loss = -tf.reduce_mean(fake_predictions)

        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(zip(gen_gradient, self.generator.trainable_variables))

        self.c_loss_metric.update_state(c_loss)
        self.c_wass_loss_metric.update_state(c_wass_loss)
        self.c_gp_metric.update_state(c_gp)
        self.g_loss_metric.update_state(g_loss)

        return {m.name: m.result() for m in self.metrics}

    def generate_piano_roll(self, num_scores):
        chords_random_latent_vectors = tf.random.normal(shape=(num_scores, Z_DIM))
        style_random_latent_vectors = tf.random.normal(shape=(num_scores, Z_DIM))
        melody_random_latent_vectors = tf.random.normal(shape=(num_scores, N_TRACKS, Z_DIM))
        groove_random_latent_vectors = tf.random.normal(shape=(num_scores, N_TRACKS, Z_DIM))
        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]
        generated_music = self.generator(random_latent_vectors)
        generated_music = generated_music.numpy()
        return generated_music

# %%
# Create a MuseGAN
musegan = MuseGAN(critic=critic, generator=generator, latent_dim=Z_DIM, critic_steps=CRITIC_STEPS, gp_weight=GP_WEIGHT)

# %%
if LOAD_MODEL:
    musegan.load_weights("./checkpoint/checkpoint.ckpt")

# %% [markdown]
# ## 3. Train the MuseGAN <a name="train"></a>

# %%
# Compile the GAN
musegan.compile(
    c_optimizer=optimizers.Adam(learning_rate=CRITIC_LEARNING_RATE, beta_1=ADAM_BETA_1, beta_2=ADAM_BETA_2),
    g_optimizer=optimizers.Adam(learning_rate=GENERATOR_LEARNING_RATE, beta_1=ADAM_BETA_1, beta_2=ADAM_BETA_2),
)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class MusicGenerator(callbacks.Callback):
    def __init__(self, num_scores):
        self.num_scores = num_scores

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 10 == 0:
            generated_music = self.model.generate_piano_roll(self.num_scores)
            notes_to_midi(generated_music, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_" + str(epoch).zfill(4))
            # display(generated_images, save_to = "./output/generated_img_%03d.png" % (epoch), cmap = None)


music_generator_callback = MusicGenerator(1)

# %%
history = musegan.fit(
    data_binary,
    epochs=EPOCHS,
    # steps_per_epoch = 10,
    # initial_epoch = 39,
    callbacks=[model_checkpoint_callback, tensorboard_callback, music_generator_callback],
)
# Out:
# Epoch 1/6000
# 8/8 [==============================] - 44s 470ms/step - c_loss: -441.3827 - c_wass_loss: -1177.6278 - c_gp: 73.6245 - g_loss: -332.4997
# Epoch 2/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -81.9011 - c_wass_loss: -181.3261 - c_gp: 9.9425 - g_loss: -671.3298
# Epoch 3/6000
# 8/8 [==============================] - 3s 399ms/step - c_loss: -56.1260 - c_wass_loss: -75.3267 - c_gp: 1.9201 - g_loss: -1128.0874
# Epoch 4/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -62.0685 - c_wass_loss: -93.7827 - c_gp: 3.1714 - g_loss: -1057.0717
# Epoch 5/6000
# 8/8 [==============================] - 4s 467ms/step - c_loss: -63.7177 - c_wass_loss: -86.8950 - c_gp: 2.3177 - g_loss: -763.2350
# Epoch 6/6000
# 8/8 [==============================] - 3s 417ms/step - c_loss: -68.1234 - c_wass_loss: -97.6190 - c_gp: 2.9496 - g_loss: -580.2043
# Epoch 7/6000
# 8/8 [==============================] - 3s 398ms/step - c_loss: -71.8057 - c_wass_loss: -102.5739 - c_gp: 3.0768 - g_loss: -460.8418
# Epoch 8/6000
# 8/8 [==============================] - 3s 399ms/step - c_loss: -76.8873 - c_wass_loss: -108.1529 - c_gp: 3.1266 - g_loss: -459.0253
# Epoch 9/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss:
6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -47.3298 - c_wass_loss: -62.8815 - c_gp: 1.5552 - g_loss: 28.9735
# Epoch 31/6000
# 8/8 [==============================] - 3s 424ms/step - c_loss: -49.5567 - c_wass_loss: -69.3527 - c_gp: 1.9796 - g_loss: -25.7084
# Epoch 32/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -48.7438 - c_wass_loss: -68.4078 - c_gp: 1.9664 - g_loss: -45.4827
# Epoch 33/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -49.4381 - c_wass_loss: -73.3389 - c_gp: 2.3901 - g_loss: 3.4617
# Epoch 34/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -48.0288 - c_wass_loss: -71.4030 - c_gp: 2.3374 - g_loss: -61.7719
# Epoch 35/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -48.0113 - c_wass_loss: -68.6610 - c_gp: 2.0650 - g_loss: -80.6400
# Epoch 36/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -47.0912 - c_wass_loss: -64.0599 - c_gp: 1.6969 - g_loss: -58.6755
# Epoch 37/6000
# 8/8 [==============================] - 3s 399ms/step - c_loss: -46.9302 - c_wass_loss: -68.0515 - c_gp: 2.1121 - g_loss: -89.2695
# Epoch 38/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -47.6070 - c_wass_loss: -67.7841 - c_gp: 2.0177 - g_loss: -96.3523
# Epoch 39/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -46.3380 - c_wass_loss: -64.0028 - c_gp: 1.7665 - g_loss: -112.9555
# Epoch 40/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -45.3738 - c_wass_loss: -63.7074 - c_gp: 1.8334 - g_loss: -123.8114
# Epoch 41/6000
# 8/8 [==============================] - 3s 422ms/step - c_loss: -44.1438 - c_wass_loss: -60.4803 - c_gp: 1.6337 - g_loss: -113.8960
# Epoch 42/6000
# 8/8 [==============================] - 3s 414ms/step - c_loss: -42.9824 - c_wass_loss: -56.9925 - c_gp: 1.4010 - g_loss: -117.7489
# Epoch 43/6000
# 8/8 [==============================] - 4s 478ms/step - c_loss: -43.7905 - c_wass_loss: -67.9266 - c_gp: 2.4136 - g_loss: -87.0053
# Epoch 44/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -42.6069 - c_wass_loss: -64.4579 - c_gp: 2.1851 - g_loss: -117.7373
# Epoch 45/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -41.4352 - c_wass_loss: -54.9227 - c_gp: 1.3488 - g_loss: -57.8735
# Epoch 46/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -43.8179 - c_wass_loss: -57.9905 - c_gp: 1.4173 - g_loss: -59.8320
# Epoch 47/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -41.1190 - c_wass_loss: -68.8677 - c_gp: 2.7749 - g_loss: -90.8765
# Epoch 48/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -39.7824 - c_wass_loss: -53.6121 - c_gp: 1.3830 - g_loss: -106.6172
# Epoch 49/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -39.5227 - c_wass_loss: -55.7914 - c_gp: 1.6269 - g_loss: -90.9816
# Epoch 50/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -37.6455 - c_wass_loss: -64.6919 - c_gp: 2.7046 - g_loss: -15.3063
# Epoch 51/6000
# 8/8 [==============================] - 3s 433ms/step - c_loss: -39.2704 - c_wass_loss: -58.6658 - c_gp: 1.9395 - g_loss: -18.9342
# Epoch 52/6000
# 8/8 [==============================] - 3s 447ms/step - c_loss: -42.0629 - c_wass_loss: -58.0941 - c_gp: 1.6031 - g_loss: 23.6381
# Epoch 53/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -41.1920 - c_wass_loss: -65.3516 - c_gp: 2.4160 - g_loss: 2.3130
# Epoch 54/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -39.5102 - c_wass_loss: -55.5042 - c_gp: 1.5994 - g_loss: 10.3144
# Epoch 55/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -41.7281 - c_wass_loss: -57.7154 - c_gp: 1.5987 - g_loss: -14.0267
# Epoch 56/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss:
6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -31.0827 - c_wass_loss: -42.7146 - c_gp: 1.1632 - g_loss: -21.3472
# Epoch 106/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -30.7794 - c_wass_loss: -41.2289 - c_gp: 1.0449 - g_loss: -10.2609
# Epoch 107/6000
# 8/8 [==============================] - 3s 453ms/step - c_loss: -31.8914 - c_wass_loss: -47.4371 - c_gp: 1.5546 - g_loss: -57.0576
# Epoch 108/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -30.4240 - c_wass_loss: -43.6027 - c_gp: 1.3179 - g_loss: -38.3808
# Epoch 109/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -31.4579 - c_wass_loss: -45.2197 - c_gp: 1.3762 - g_loss: 25.5260
# Epoch 110/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -33.6381 - c_wass_loss: -48.6925 - c_gp: 1.5054 - g_loss: -27.7990
# Epoch 111/6000
# 8/8 [==============================] - 3s 431ms/step - c_loss: -30.3362 - c_wass_loss: -44.9622 - c_gp: 1.4626 - g_loss: -0.3843
# Epoch 112/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -31.2793 - c_wass_loss: -41.7801 - c_gp: 1.0501 - g_loss: -12.9435
# Epoch 113/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -30.6242 - c_wass_loss: -40.2587 - c_gp: 0.9635 - g_loss: -31.3432
# Epoch 114/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -33.2170 - c_wass_loss: -45.4635 - c_gp: 1.2246 - g_loss: 21.4510
# Epoch 115/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -25.0332 - c_wass_loss: -47.9090 - c_gp: 2.2876 - g_loss: -42.6482
# Epoch 116/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -27.9589 - c_wass_loss: -42.6312 - c_gp: 1.4672 - g_loss: -38.6583
# Epoch 117/6000
# 8/8 [==============================] - 4s 466ms/step - c_loss: -31.8532 - c_wass_loss: -43.0152 - c_gp: 1.1162 - g_loss: -4.9587
# Epoch 118/6000
# 8/8 [==============================] - 3s 429ms/step - c_loss: -31.1433 - c_wass_loss: -47.5723 - c_gp: 1.6429 - g_loss: -94.7077
# Epoch 119/6000
# 8/8 [==============================] - 3s 387ms/step - c_loss: -24.9795 - c_wass_loss: -45.0224 - c_gp: 2.0043 - g_loss: 1.4347
# Epoch 120/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -29.6022 - c_wass_loss: -42.3318 - c_gp: 1.2730 - g_loss: -22.5440
# Epoch 121/6000
# 8/8 [==============================] - 3s 422ms/step - c_loss: -30.8993 - c_wass_loss: -42.0089 - c_gp: 1.1110 - g_loss: 17.4574
# Epoch 122/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -30.1521 - c_wass_loss: -47.3444 - c_gp: 1.7192 - g_loss: -63.6856
# Epoch 123/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -30.5871 - c_wass_loss: -43.2451 - c_gp: 1.2658 - g_loss: -6.7933
# Epoch 124/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -27.7373 - c_wass_loss: -44.5988 - c_gp: 1.6861 - g_loss: -33.9669
# Epoch 125/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -32.3082 - c_wass_loss: -53.3842 - c_gp: 2.1076 - g_loss: -102.9589
# Epoch 126/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -28.4022 - c_wass_loss: -44.9791 - c_gp: 1.6577 - g_loss: -65.4685
# Epoch 127/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -29.6915 - c_wass_loss: -43.3809 - c_gp: 1.3689 - g_loss: -70.5620
# Epoch 128/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -28.0668 - c_wass_loss: -49.1914 - c_gp: 2.1125 - g_loss: -30.4468
# Epoch 129/6000
# 8/8 [==============================] - 3s 398ms/step - c_loss: -31.6005 - c_wass_loss: -42.6362 - c_gp: 1.1036 - g_loss: -59.1080
# Epoch 130/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss:
6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -25.9229 - c_wass_loss: -41.1008 - c_gp: 1.5178 - g_loss: -33.4547
# Epoch 157/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -26.6322 - c_wass_loss: -37.9913 - c_gp: 1.1359 - g_loss: -73.7102
# Epoch 158/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -28.6162 - c_wass_loss: -41.2347 - c_gp: 1.2618 - g_loss: -114.3773
# Epoch 159/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -27.8666 - c_wass_loss: -38.0252 - c_gp: 1.0159 - g_loss: 0.1883
# Epoch 160/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -27.0301 - c_wass_loss: -36.6620 - c_gp: 0.9632 - g_loss: -92.4466
# Epoch 161/6000
# 8/8 [==============================] - 3s 427ms/step - c_loss: -27.2249 - c_wass_loss: -40.5715 - c_gp: 1.3347 - g_loss: 18.4740
# Epoch 162/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -28.3966 - c_wass_loss: -36.2070 - c_gp: 0.7810 - g_loss: -24.6530
# Epoch 163/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -14.4743 - c_wass_loss: -49.3714 - c_gp: 3.4897 - g_loss: -79.2123
# Epoch 164/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -26.2424 - c_wass_loss: -40.6296 - c_gp: 1.4387 - g_loss: -31.0453
# Epoch 165/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -26.5816 - c_wass_loss: -40.8174 - c_gp: 1.4236 - g_loss: -37.5350
# Epoch 166/6000
# 8/8 [==============================] - 3s 451ms/step - c_loss: -28.4432 - c_wass_loss: -38.2524 - c_gp: 0.9809 - g_loss: -90.8946
# Epoch 167/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -25.5781 - c_wass_loss: -42.4205 - c_gp: 1.6842 - g_loss: 15.0410
# Epoch 168/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -24.2122 - c_wass_loss: -36.8217 - c_gp: 1.2609 - g_loss: -119.2212
# Epoch 169/6000
# 8/8 [==============================] - 3s 407ms/step - c_loss: -26.6279 - c_wass_loss: -38.1274 - c_gp: 1.1499 - g_loss: -41.0768
# Epoch 170/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -27.2962 - c_wass_loss: -35.2771 - c_gp: 0.7981 - g_loss: -4.6357
# Epoch 171/6000
# 8/8 [==============================] - 3s 430ms/step - c_loss: -24.2182 - c_wass_loss: -41.5731 - c_gp: 1.7355 - g_loss: -47.1950
# Epoch 172/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -14.6674 - c_wass_loss: -47.9149 - c_gp: 3.3248 - g_loss: 42.9030
# Epoch 173/6000
# 8/8 [==============================] - 4s 459ms/step - c_loss: -26.3371 - c_wass_loss: -37.0972 - c_gp: 1.0760 - g_loss: -57.0392
# Epoch 174/6000
# 8/8 [==============================] - 3s 422ms/step - c_loss: -30.2103 - c_wass_loss: -38.8772 - c_gp: 0.8667 - g_loss: -122.2422
# Epoch 175/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -28.7782 - c_wass_loss: -39.2355 - c_gp: 1.0457 - g_loss: 7.2205
# Epoch 176/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.9195 - c_wass_loss: -35.8744 - c_gp: 0.9955 - g_loss: -82.0511
# Epoch 177/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -27.2157 - c_wass_loss: -41.7037 - c_gp: 1.4488 - g_loss: -71.4089
# Epoch 178/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -26.5630 - c_wass_loss: -36.9665 - c_gp: 1.0404 - g_loss: -48.4003
# Epoch 179/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -26.6246 - c_wass_loss: -36.0562 - c_gp: 0.9432 - g_loss: -30.7897
# Epoch 180/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -23.8933 - c_wass_loss: -37.0621 - c_gp: 1.3169 - g_loss: -45.9541
# Epoch 181/6000
# 8/8 [==============================] - 3s 429ms/step - c_loss: -24.7470 - c_wass_loss: -42.4865 - c_gp: 1.7739 - g_loss: -109.8630
# Epoch 182/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -25.5549 - c_wass_loss: -39.0524 - c_gp: 1.3497 - g_loss: -22.2679
# Epoch 183/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -28.1431 - c_wass_loss: -40.7322 - c_gp: 1.2589 - g_loss: -25.0186
# Epoch 184/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -26.2469 - c_wass_loss: -39.2018 - c_gp: 1.2955 - g_loss: -137.3585
# Epoch 185/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -26.3653 - c_wass_loss: -35.8974 - c_gp: 0.9532 - g_loss: -15.4788
# Epoch 186/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -24.7034 - c_wass_loss: -37.9628 - c_gp: 1.3259 - g_loss: 11.8447
# Epoch 187/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.1387 - c_wass_loss: -36.5591 - c_gp: 1.1420 - g_loss: -62.0002
# Epoch 188/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -27.5363 - c_wass_loss: -42.2730 - c_gp: 1.4737 - g_loss: -42.0844
# Epoch 189/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.5984 - c_wass_loss: -35.8120 - c_gp: 1.0214 - g_loss: 1.0078
# Epoch 190/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -26.9291 - c_wass_loss: -35.9299 - c_gp: 0.9001 - g_loss: -0.6757
# Epoch 191/6000
# 8/8 [==============================] - 3s 428ms/step - c_loss: -26.0989 - c_wass_loss: -35.1828 - c_gp: 0.9084 - g_loss: -12.9811
# Epoch 192/6000
# 8/8 [==============================] - 4s 476ms/step - c_loss: -27.1446 - c_wass_loss: -37.0366 - c_gp: 0.9892 - g_loss: -78.9719
# Epoch 193/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -27.4420 - c_wass_loss: -36.0937 - c_gp: 0.8652 - g_loss: -89.4458
# Epoch 194/6000
# 8/8 [==============================] - 4s 457ms/step - c_loss: -28.2808 - c_wass_loss: -36.2165 - c_gp: 0.7936 - g_loss: -75.2951
# Epoch 195/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.4535 - c_wass_loss: -35.4619 - c_gp: 1.0008 - g_loss: -24.2879
# Epoch 196/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -24.2794 - c_wass_loss: -38.7480 - c_gp: 1.4469 - g_loss: -64.2307
# Epoch 197/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -24.5248 - c_wass_loss: -35.0368 - c_gp: 1.0512 - g_loss: 1.4830
# Epoch 198/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -27.9833 - c_wass_loss: -38.6101 - c_gp: 1.0627 - g_loss: -68.6583
# Epoch 199/6000
# 8/8 [==============================] - 3s 397ms/step - c_loss: -20.7341 - c_wass_loss: -42.1811 - c_gp: 2.1447 - g_loss: -149.8852
# Epoch 200/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -25.8002 - c_wass_loss: -36.0855 - c_gp: 1.0285 - g_loss: -168.7286
# Epoch 201/6000
# 8/8 [==============================] - 3s 416ms/step - c_loss: -26.4122 - c_wass_loss: -35.0502 - c_gp: 0.8638 - g_loss: -51.7670
# Epoch 202/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -25.2918 - c_wass_loss: -36.0908 - c_gp: 1.0799 - g_loss: -73.3640
# Epoch 203/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.4548 - c_wass_loss: -34.5950 - c_gp: 0.9140 - g_loss: -3.8022
# Epoch 204/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -25.4648 - c_wass_loss: -35.9848 - c_gp: 1.0520 - g_loss: -26.9086
# Epoch 205/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -21.0089 - c_wass_loss: -36.2802 - c_gp: 1.5271 - g_loss: -57.6453
# Epoch 206/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -26.1243 - c_wass_loss: -33.7074 - c_gp: 0.7583 - g_loss: -44.4768
# Epoch 207/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -24.6387 - c_wass_loss: -36.8205 - c_gp: 1.2182 - g_loss: 40.6319
# Epoch 208/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -24.6977 - c_wass_loss: -37.0370 - c_gp: 1.2339 - g_loss: -77.7609
# Epoch 209/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -25.4149 - c_wass_loss: -40.9743 - c_gp: 1.5559 - g_loss: 19.3374
# Epoch 210/6000
# 8/8 [==============================] - 3s 443ms/step - c_loss: -22.0932 - c_wass_loss: -41.1549 - c_gp: 1.9062 - g_loss: -8.2572
# Epoch 211/6000
# 8/8 [==============================] - 4s 487ms/step - c_loss: -24.5100 - c_wass_loss: -35.7240 - c_gp: 1.1214 - g_loss: -83.1025
# Epoch 212/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -24.9982 - c_wass_loss: -37.6843 - c_gp: 1.2686 - g_loss: -30.2182
# Epoch 213/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -25.8945 - c_wass_loss: -33.8118 - c_gp: 0.7917 - g_loss: -59.0674
# Epoch 214/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -20.6519 - c_wass_loss: -41.6175 - c_gp: 2.0966 - g_loss: -37.6006
# Epoch 215/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -24.0437 - c_wass_loss: -35.7926 - c_gp: 1.1749 - g_loss: 13.2503
# Epoch 216/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -21.8910 - c_wass_loss: -44.2164 - c_gp: 2.2325 - g_loss: -65.1952
# Epoch 217/6000
# 8/8 [==============================] - 3s 396ms/step - c_loss: -23.5449 - c_wass_loss: -37.1347 - c_gp: 1.3590 - g_loss: -24.4552
# Epoch 218/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -24.7399 - c_wass_loss: -37.3828 - c_gp: 1.2643 - g_loss: -116.9882
# Epoch 219/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -26.1283 - c_wass_loss: -49.5045 - c_gp: 2.3376 - g_loss: -54.4552
# Epoch 220/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -25.9213 - c_wass_loss: -35.4984 - c_gp: 0.9577 - g_loss: 47.7085
# Epoch 221/6000
# 8/8 [==============================] - 3s 424ms/step - c_loss: -26.4986 - c_wass_loss: -35.0497 - c_gp: 0.8551 - g_loss: -114.1560
# Epoch 222/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -26.5308 - c_wass_loss: -35.2378 - c_gp: 0.8707 - g_loss: -15.7406
# Epoch 223/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -24.7525 - c_wass_loss: -31.0356 - c_gp: 0.6283 - g_loss: -34.0589
# Epoch 224/6000
# 8/8 [==============================] - 3s 448ms/step - c_loss: -26.3471 - c_wass_loss: -35.3380 - c_gp: 0.8991 - g_loss: -17.4994
# Epoch 225/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -22.3562 - c_wass_loss: -39.8634 - c_gp: 1.7507 - g_loss: 15.2398
# Epoch 226/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -23.1523 - c_wass_loss: -30.2687 - c_gp: 0.7116 - g_loss: -99.2238
# Epoch 227/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -20.5592 - c_wass_loss: -40.1496 - c_gp: 1.9590 - g_loss: -32.2269
# Epoch 228/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -24.9622 - c_wass_loss: -38.5829 - c_gp: 1.3621 - g_loss: 45.4805
# Epoch 229/6000
# 8/8 [==============================] - 3s 450ms/step - c_loss: -18.9364 - c_wass_loss: -39.9575 - c_gp: 2.1021 - g_loss: -34.5775
# Epoch 230/6000
# 8/8 [==============================] - 4s 461ms/step - c_loss: -24.1416 - c_wass_loss: -31.3848 - c_gp: 0.7243 - g_loss: -91.4863
# Epoch 231/6000
# 8/8 [==============================] - 3s 428ms/step - c_loss: -24.2626 - c_wass_loss: -35.5764 - c_gp: 1.1314 - g_loss: -3.0702
# Epoch 232/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -24.9150 - c_wass_loss: -33.5723 - c_gp: 0.8657 - g_loss: -61.2035
# Epoch 233/6000
# 8/8 [==============================] - 3s 407ms/step - c_loss: -24.1992 - c_wass_loss: -35.5674 - c_gp: 1.1368 - g_loss: -10.1778
# Epoch 234/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -9.4799 - c_wass_loss: -45.8896 - c_gp: 3.6410 - g_loss: -131.4215
# Epoch 235/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.5539 - c_wass_loss: -33.9726 - c_gp: 0.8419 - g_loss: -9.1161
# Epoch 236/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -22.4945 - c_wass_loss: -36.5362 - c_gp: 1.4042 - g_loss: -35.2575
# Epoch 237/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -25.3565 - c_wass_loss: -33.9271 - c_gp: 0.8571 - g_loss: 42.8684
# Epoch 238/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -25.5769 - c_wass_loss: -33.1689 - c_gp: 0.7592 - g_loss: -9.6759
# Epoch 239/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -25.1052 - c_wass_loss: -40.5191 - c_gp: 1.5414 - g_loss: 0.6934
# Epoch 240/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -24.7882 - c_wass_loss: -31.8927 - c_gp: 0.7105 - g_loss: 25.4011
# Epoch 241/6000
# 8/8 [==============================] - 3s 422ms/step - c_loss: -24.6797 - c_wass_loss: -30.5877 - c_gp: 0.5908 - g_loss: 1.3666
# Epoch 242/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -22.7972 - c_wass_loss: -33.3560 - c_gp: 1.0559 - g_loss: -75.7033
# Epoch 243/6000
# 8/8 [==============================] - 3s 407ms/step - c_loss: -24.7089 - c_wass_loss: -33.8824 - c_gp: 0.9174 - g_loss: -38.6205
# Epoch 244/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -23.5699 - c_wass_loss: -37.4110 - c_gp: 1.3841 - g_loss: -28.8701
# Epoch 245/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -24.4993 - c_wass_loss: -37.1045 - c_gp: 1.2605 - g_loss: 27.4616
# Epoch 246/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -26.7864 - c_wass_loss: -38.4198 - c_gp: 1.1633 - g_loss: -8.6057
# Epoch 247/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.8995 - c_wass_loss: -33.9860 - c_gp: 0.8087 - g_loss: -50.2356
# Epoch 248/6000
# 8/8 [==============================] - 4s 474ms/step - c_loss: -23.1781 - c_wass_loss: -31.6562 - c_gp: 0.8478 - g_loss: -127.7507
# Epoch 249/6000
# 8/8 [==============================] - 3s 430ms/step - c_loss: -24.9702 - c_wass_loss: -31.5148 - c_gp: 0.6545 - g_loss: -67.1480
# Epoch 250/6000
# 8/8 [==============================] - 3s 398ms/step - c_loss: -14.2641 - c_wass_loss: -47.7409 - c_gp: 3.3477 - g_loss: -38.9330
# Epoch 251/6000
# 8/8 [==============================] - 3s 424ms/step - c_loss: -23.5154 - c_wass_loss: -35.7347 - c_gp: 1.2219 - g_loss: -14.5175
# Epoch 252/6000
# 8/8 [==============================] - 3s 390ms/step - c_loss: -24.3235 - c_wass_loss: -43.0634 - c_gp: 1.8740 - g_loss: -3.9928
# Epoch 253/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.4594 - c_wass_loss: -33.6131 - c_gp: 0.8154 - g_loss: -3.1246
# Epoch 254/6000
# 8/8 [==============================] - 3s 447ms/step - c_loss: -14.0655 - c_wass_loss: -48.4802 - c_gp: 3.4415 - g_loss: 0.4647
# Epoch 255/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -24.0496 - c_wass_loss: -35.8402 - c_gp: 1.1791 - g_loss: 20.7574
# Epoch 256/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -24.2333 - c_wass_loss: -31.8615 - c_gp: 0.7628 - g_loss: -54.9495
# Epoch 257/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -22.6789 - c_wass_loss: -39.1067 - c_gp: 1.6428 - g_loss: -13.1582
# Epoch 258/6000
# 8/8 [==============================] - 3s 392ms/step - c_loss: -23.2592 - c_wass_loss: -35.0822 - c_gp: 1.1823 - g_loss: -73.8282
# Epoch 259/6000
# 8/8 [==============================] - 3s 406ms/step - c_loss: -24.0817 - c_wass_loss: -32.9470 - c_gp: 0.8865 - g_loss: -14.5095
# Epoch 260/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -27.1725 - c_wass_loss: -37.6273 - c_gp: 1.0455 - g_loss: 1.3239
# Epoch 261/6000
# 8/8 [==============================] - 3s 420ms/step - c_loss: -24.4644 - c_wass_loss: -33.2206 - c_gp: 0.8756 - g_loss: -71.9285
# Epoch 262/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -23.7262 - c_wass_loss: -33.5931 - c_gp: 0.9867 - g_loss: -3.4454
# Epoch 263/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -24.1609 - c_wass_loss: -35.7126 - c_gp: 1.1552 - g_loss: 35.7625
# Epoch 264/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -26.3085 - c_wass_loss: -34.8606 - c_gp: 0.8552 - g_loss: -22.3803
# Epoch 265/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -25.5319 - c_wass_loss: -36.7095 - c_gp: 1.1178 - g_loss: -23.3938
# Epoch 266/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -23.6220 - c_wass_loss: -30.9573 - c_gp: 0.7335 - g_loss: -139.7423
# Epoch 267/6000
# 8/8 [==============================] - 4s 475ms/step - c_loss: -25.4623 - c_wass_loss: -35.2510 - c_gp: 0.9789 - g_loss: -3.7241
# Epoch 268/6000
# 8/8 [==============================] - 3s 407ms/step - c_loss: -25.5910 - c_wass_loss: -37.2913 - c_gp: 1.1700 - g_loss: -69.4401
# Epoch 269/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -26.6512 - c_wass_loss: -36.0211 - c_gp: 0.9370 - g_loss: -47.5926
# Epoch 270/6000
# 8/8 [==============================] - 3s 398ms/step - c_loss: -25.2769 - c_wass_loss: -34.9693 - c_gp: 0.9692 - g_loss: -44.0196
# Epoch 271/6000
# 8/8 [==============================] - 3s 424ms/step - c_loss: -24.1469 - c_wass_loss: -34.8028 - c_gp: 1.0656 - g_loss: -36.9346
# Epoch 272/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -23.9581 - c_wass_loss: -34.5109 - c_gp: 1.0553 - g_loss: 7.8428
# Epoch 273/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -24.1320 - c_wass_loss: -33.8191 - c_gp: 0.9687 - g_loss: 50.6325
# Epoch 274/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -24.2164 - c_wass_loss: -31.1642 - c_gp: 0.6948 - g_loss: -11.2644
# Epoch 275/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -25.4069 - c_wass_loss: -32.1494 - c_gp: 0.6742 - g_loss: -14.6119
# Epoch 276/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -23.1936 - c_wass_loss: -34.7316 - c_gp: 1.1538 - g_loss: -65.0972
# Epoch 277/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -24.5457 - c_wass_loss: -38.8173 - c_gp: 1.4272 - g_loss: 42.9922
# Epoch 278/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -21.1593 - c_wass_loss: -41.7155 - c_gp: 2.0556 - g_loss: 25.3929
# Epoch 279/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -23.3968 - c_wass_loss: -33.8189 - c_gp: 1.0422 - g_loss: 10.5583
# Epoch 280/6000
# 8/8 [==============================] - 3s 455ms/step - c_loss: -26.3777 - c_wass_loss: -35.4576 - c_gp: 0.9080 - g_loss: 39.0958
# Epoch 281/6000
# 8/8 [==============================] - 3s 420ms/step - c_loss: -24.9022 - c_wass_loss: -39.3841 - c_gp: 1.4482 - g_loss: 18.8126
# Epoch 282/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -23.5161 - c_wass_loss: -37.6852 - c_gp: 1.4169 - g_loss: -7.1198
# Epoch 283/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -15.1182 - c_wass_loss: -49.5729 - c_gp: 3.4455 - g_loss: 10.4634
# Epoch 284/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -24.2873 - c_wass_loss: -33.5932 - c_gp: 0.9306 - g_loss: -69.5944
# Epoch 285/6000
# 8/8 [==============================] - 4s 459ms/step - c_loss: -27.0379 - c_wass_loss: -36.1303 - c_gp: 0.9092 - g_loss: -79.4803
# Epoch 286/6000
# 8/8 [==============================] - 4s 468ms/step - c_loss: -26.0168 - c_wass_loss: -43.2216 - c_gp: 1.7205 - g_loss: -61.0187
# Epoch 287/6000
# 8/8 [==============================] - 3s 404ms/step - c_loss: -27.7107 - c_wass_loss: -35.2196 - c_gp: 0.7509 - g_loss: -178.0372
# Epoch 288/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -24.9397 - c_wass_loss: -34.8299 - c_gp: 0.9890 - g_loss: -117.4198
# Epoch 289/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -25.0379 - c_wass_loss: -44.2203 - c_gp: 1.9182 - g_loss: -73.7141
# Epoch 290/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -26.7621 - c_wass_loss: -37.8106 - c_gp: 1.1048 - g_loss: 53.4440
# Epoch 291/6000
# 8/8 [==============================] - 3s 423ms/step - c_loss: -26.8166 - c_wass_loss: -37.7455 - c_gp: 1.0929 - g_loss: -41.5235
# Epoch 292/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -26.5209 - c_wass_loss: -33.2627 - c_gp: 0.6742 - g_loss: 11.3611
# Epoch 293/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -22.5532 - c_wass_loss: -34.7799 - c_gp: 1.2227 - g_loss: -39.3633
# Epoch 294/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -23.6295 - c_wass_loss: -41.1841 - c_gp: 1.7555 - g_loss: -10.6812
# Epoch 295/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -24.8878 - c_wass_loss: -43.5900 - c_gp: 1.8702 - g_loss: -41.1291
# Epoch 296/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -24.7746 - c_wass_loss: -32.7998 - c_gp: 0.8025 - g_loss: 8.0574
# Epoch 297/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -24.9379 - c_wass_loss: -37.3633 - c_gp: 1.2425 - g_loss: 37.4236
# Epoch 298/6000
# 8/8 [==============================] - 3s 395ms/step - c_loss: -22.1871 - c_wass_loss: -42.1146 - c_gp: 1.9928 - g_loss: -81.1584
# Epoch 299/6000
# 8/8 [==============================] - 3s 394ms/step - c_loss: -28.4775 - c_wass_loss: -35.9562 - c_gp: 0.7479 - g_loss: 72.9220
# Epoch 300/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -26.3704 - c_wass_loss: -36.2669 - c_gp: 0.9897 - g_loss: -44.8237
# Epoch 301/6000
# 8/8 [==============================] - 3s 428ms/step - c_loss: -26.3738 - c_wass_loss: -44.2568 - c_gp: 1.7883 - g_loss: 38.3432
# Epoch 302/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -21.5721 - c_wass_loss: -34.9768 - c_gp: 1.3405 - g_loss: 19.0614
# Epoch 303/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -25.6145 - c_wass_loss: -36.9658 - c_gp: 1.1351 - g_loss: -19.8601
# Epoch 304/6000
# 8/8 [==============================] - 3s 454ms/step - c_loss: -25.6422 - c_wass_loss: -37.8493 - c_gp: 1.2207 - g_loss: -10.5327
# Epoch 305/6000
# 8/8 [==============================] - 4s 463ms/step - c_loss: -28.6187 - c_wass_loss: -39.7190 - c_gp: 1.1100 - g_loss: -39.5449
# Epoch 306/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -25.7517 - c_wass_loss: -33.6292 - c_gp: 0.7878 - g_loss: 17.3832
# Epoch 307/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -27.0773 - c_wass_loss: -34.9316 - c_gp: 0.7854 - g_loss: 10.7466
# Epoch 308/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -26.6319 - c_wass_loss: -37.0733 - c_gp: 1.0441 - g_loss: -158.3735
# Epoch 309/6000
# 8/8 [==============================] - 3s 455ms/step - c_loss: -25.7866 - c_wass_loss: -35.3513 - c_gp: 0.9565 - g_loss: 64.0270
# Epoch 310/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -26.2411 - c_wass_loss: -39.8646 - c_gp: 1.3624 - g_loss: -46.1464
# Epoch 311/6000
# 8/8 [==============================] - 3s 412ms/step - c_loss: -26.2538 - c_wass_loss: -34.4660 - c_gp: 0.8212 - g_loss: -24.8449
# Epoch 312/6000
# 8/8 [==============================] - 3s 405ms/step - c_loss: -25.4701 - c_wass_loss: -35.3964 - c_gp: 0.9926 - g_loss: 79.7961
# Epoch 313/6000
# 8/8 [==============================] - 3s 394ms/step - c_loss: -25.0413 - c_wass_loss: -33.8547 - c_gp: 0.8813 - g_loss: 28.3668
# Epoch 314/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -25.4736 - c_wass_loss: -34.2650 - c_gp: 0.8791 - g_loss: -17.2399
# Epoch 315/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.1980 - c_wass_loss: -42.6385 - c_gp: 1.7440 - g_loss: -105.4850
# Epoch 316/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -24.6222 - c_wass_loss: -32.0654 - c_gp: 0.7443 - g_loss: -1.5903
# Epoch 317/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -27.2646 - c_wass_loss: -38.2146 - c_gp: 1.0950 - g_loss: -84.7209
# Epoch 318/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.2868 - c_wass_loss: -38.0231 - c_gp: 1.2736 - g_loss: 68.7887
# Epoch 319/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -26.4741 - c_wass_loss: -42.0978 - c_gp: 1.5624 - g_loss: -98.0009
# Epoch 320/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -23.8613 - c_wass_loss: -34.4621 - c_gp: 1.0601 - g_loss: -23.4023
# Epoch 321/6000
# 8/8 [==============================] - 3s 429ms/step - c_loss: -15.4190 - c_wass_loss: -42.4070 - c_gp: 2.6988 - g_loss: 13.2003
# Epoch 322/6000
# 8/8 [==============================] - 3s 402ms/step - c_loss: -28.5750 - c_wass_loss: -38.6988 - c_gp: 1.0124 - g_loss: -28.2358
# Epoch 323/6000
# 8/8 [==============================] - 4s 472ms/step - c_loss: -25.3340 - c_wass_loss: -34.4917 - c_gp: 0.9158 - g_loss: 132.8537
# Epoch 324/6000
# 8/8 [==============================] - 3s 416ms/step - c_loss: -25.1182 - c_wass_loss: -37.2813 - c_gp: 1.2163 - g_loss: -25.3372
# Epoch 325/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -25.4979 - c_wass_loss: -37.5869 - c_gp: 1.2089 - g_loss: 32.7873
# Epoch 326/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -24.8514 - c_wass_loss: -35.9827 - c_gp: 1.1131 - g_loss: -0.7760
# Epoch 327/6000
# 8/8 [==============================] - 3s 399ms/step - c_loss: -26.8066 - c_wass_loss: -37.8904 - c_gp: 1.1084 - g_loss: -77.0285
# Epoch 328/6000
# 8/8 [==============================] - 3s 408ms/step - c_loss: -26.3674 - c_wass_loss: -36.6736 - c_gp: 1.0306 - g_loss: -4.4871
# Epoch 329/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -26.9000 - c_wass_loss: -37.3059 - c_gp: 1.0406 - g_loss: 12.3000
# Epoch 330/6000
# 8/8 [==============================] - 3s 410ms/step - c_loss: -25.6549 - c_wass_loss: -37.3153 - c_gp: 1.1660 - g_loss: -67.2620
# Epoch 331/6000
# 8/8 [==============================] - 3s 423ms/step - c_loss: -27.3805 - c_wass_loss: -36.3619 - c_gp: 0.8981 - g_loss: -106.0654
# Epoch 332/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss: -27.3633 - c_wass_loss: -41.5630 - c_gp: 1.4200 - g_loss: 10.2187
# Epoch 333/6000
# ...
# Epoch 1522/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -69.2148 - c_wass_loss: -129.9444 - c_gp: 6.0730 - g_loss: 36.8162
# Epoch 1523/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -91.6384 - c_wass_loss: -133.8601 - c_gp: 4.2222 - g_loss: 54.1315
# Epoch 1524/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -70.5346 - c_wass_loss: -123.5432 - c_gp: 5.3009 - g_loss: 44.8234
# Epoch 1525/6000
# 8/8 [==============================] - 3s 396ms/step - c_loss: -66.8341 - c_wass_loss: -133.2272 - c_gp: 6.6393 - g_loss: 40.2856
# Epoch 1526/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -84.7859 - c_wass_loss: -128.2515 - c_gp: 4.3466 - g_loss: 51.9058
# Epoch 1527/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -88.1794 - c_wass_loss: -129.1782 - c_gp: 4.0999 - g_loss: 27.0366
# Epoch 1528/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -64.9147 - c_wass_loss: -138.5539 - c_gp: 7.3639 - g_loss: 43.9127
# Epoch 1529/6000
# 8/8 [==============================] - 4s 461ms/step - c_loss: -78.8987 - c_wass_loss: -134.4431 - c_gp: 5.5544 - g_loss: 43.6807
# Epoch 1530/6000
# 8/8 [==============================] - 3s 423ms/step - c_loss: -45.2012 - c_wass_loss: -139.0226 - c_gp: 9.3821 - g_loss: 47.7666
# Epoch 1531/6000
# 8/8 [==============================] - 3s 419ms/step - c_loss: -72.8656 - c_wass_loss: -127.3181 - c_gp: 5.4452 - g_loss: 31.8545
# Epoch 1532/6000
# 8/8 [==============================] - 3s 401ms/step - c_loss: -70.5647 - c_wass_loss: -129.5178 - c_gp: 5.8953 - g_loss: 59.7628
# Epoch 1533/6000
# 8/8 [==============================] - 3s 409ms/step - c_loss:
6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -58.7579 - c_wass_loss: -121.7654 - c_gp: 6.3008 - g_loss: 39.3520
# Epoch 1627/6000
# 8/8 [==============================] - 3s 400ms/step - c_loss: -65.9142 - c_wass_loss: -129.9456 - c_gp: 6.4031 - g_loss: 25.8760
# Epoch 1628/6000
# 8/8 [==============================] - 3s 411ms/step - c_loss: -82.4502 - c_wass_loss: -127.3198 - c_gp: 4.4870 - g_loss: 28.5035
# Epoch 1629/6000
# 8/8 [==============================] - 3s 403ms/step - c_loss: -57.8193 - c_wass_loss: -141.9118 - c_gp: 8.4092 - g_loss: 32.8418
# Epoch 1630/6000
# 8/8 [==============================] - ETA: 0s - c_loss: -81.8802 - c_wass_loss: -118.2630 - c_gp: 3.6383 - g_loss: 37.4055

# %% [markdown]
# # Generate new scores

# %%
num_scores = 1
chords_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
style_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
melody_random_latent_vectors = np.random.normal(size=(num_scores, N_TRACKS, Z_DIM))
groove_random_latent_vectors = np.random.normal(size=(num_scores, N_TRACKS, Z_DIM))
random_latent_vectors = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music = generator(random_latent_vectors)
generated_music = generated_music.numpy()

draw_score(generated_music, 0)
notes_to_midi(generated_music, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi")

# %% [markdown]
# ## Changing Chord Noise

# %%
chords_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_2 = [
    chords_random_latent_vectors_2,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_2 = generator(random_latent_vectors_2)
generated_music_2 = generated_music_2.numpy()
draw_score(generated_music_2, 0)
notes_to_midi(generated_music_2, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi_chords_changed")

# %% [markdown]
# # Changing Style Noise

# %%
style_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_3 = [
    chords_random_latent_vectors,
    style_random_latent_vectors_2,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_3 = generator(random_latent_vectors_3)
generated_music_3 = generated_music_3.numpy()
draw_score(generated_music_3, 0)
notes_to_midi(generated_music_3, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi_style_changed")

# %% [markdown]
# ## Changing Melody Noise

# %%
melody_random_latent_vectors_2 = np.copy(melody_random_latent_vectors)
melody_random_latent_vectors_2[:, 0, :] = np.random.normal(size=(num_scores, Z_DIM))

random_latent_vectors_4 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors_2,
    groove_random_latent_vectors,
]
generated_music_4 = generator(random_latent_vectors_4)
generated_music_4 = generated_music_4.numpy()
draw_score(generated_music_4, 0)
notes_to_midi(generated_music_4, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi_melody_changed")

# %% [markdown]
# ## Changing groove noise

# %%
groove_random_latent_vectors_2 = np.copy(groove_random_latent_vectors)
groove_random_latent_vectors_2[:, -1, :] = np.random.normal(size=(num_scores, Z_DIM))

random_latent_vectors_5 = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors_2,
]
generated_music_5 = generator(random_latent_vectors_5)
generated_music_5 = generated_music_5.numpy()
draw_score(generated_music_5, 0)
notes_to_midi(generated_music_5, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi_groove_changed")
